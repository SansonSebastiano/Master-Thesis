# %% [markdown]
# # Imports

# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import wandb
import copy
from tabulate import tabulate
import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import odds_datasets
import warnings
warnings.filterwarnings('ignore')

from diffi.utils import *

# %% [markdown]
# Setting up W&B

# %%
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: sanson-sebastiano-00 (sanson-sebastiano-00-universita-di-padova) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# Setting a seed value for reproducibility

# %%
np.random.seed(0)

# %% [markdown]
# # Helper functions

# %% [markdown]
# ## Logging

# %%
def log_feature_importance(feature_importances, threshold_type, og_model: bool):
    """
    Log feature importance plot to Weights & Biases.

    Args:
        feature_importances (np.ndarray): Array of feature importances.
        threshold_type (str): Type of thresholding used for feature selection.
        og_model (bool): Flag indicating if the model is original or pruned.
    """

    sorted_indices = np.argsort(feature_importances)[::-1]
    fi_std = np.std(feature_importances)

    plt.figure(figsize=(10, 5))
    plt.grid(True, axis='y', linestyle='--', alpha=0.7, zorder=0)
    plt.bar(range(len(sorted_indices)), feature_importances[sorted_indices], 
            yerr=fi_std, zorder=3)
    plt.xticks(range(len(sorted_indices)), sorted_indices)
    plt.xlabel('Feature Index')
    plt.ylabel('Feature Importance')
    plt.ylim(bottom=0)
    if og_model:
        plt.title('Feature Importance - Original Model')
        wandb.log({f"threshold_type_{threshold_type}/feature_importance_original": wandb.Image(plt)})
    else:
        plt.title('Feature Importance - Pruned Model')
        wandb.log({f"threshold_type_{threshold_type}/feature_importance_pruned": wandb.Image(plt)})
    plt.close()

# %%
def log_fi_heatmap(fis_in, fis_out, threshold_type, seed, is_og_model: bool):
    """
    Log feature importance heatmaps to wandb with inliers and outliers side-by-side.
    
    Args:
        fis_in (list): List of feature importance matrices for inliers, one per forest.
        fis_out (list): List of feature importance matrices for outliers, one per forest.
        threshold_type (str): Type of thresholding used for feature selection.
    """
    num_forests = len(fis_in)
    assert len(fis_out) == num_forests, "Number of forests doesn't match between inliers and outliers"
    
    for i in range(num_forests):
        fig, axes = plt.subplots(1, 2, figsize=(20, 8))
        
        # Inliers heatmap
        sns.heatmap(fis_in[i], cmap='viridis', cbar=True, vmin=0, vmax=0.16, ax=axes[0])
        if is_og_model:
            axes[0].set_title(f'Original Model Feature Importance - Inliers (Forest {i+1})', fontsize=14)
        else:
            axes[0].set_title(f'Pruned Model Feature Importance - Inliers (Forest {i+1})', fontsize=14)
        axes[0].set_xlabel('Feature Index')
        axes[0].set_ylabel('Tree Index')
        
        # Outliers heatmap 
        sns.heatmap(fis_out[i], cmap='viridis', cbar=True, vmin=0, vmax=0.16, ax=axes[1])
        if is_og_model:
            axes[1].set_title(f'Original Model Feature Importance - Outliers (Forest {i+1})', fontsize=14)
        else:   
            axes[1].set_title(f'Pruned Model Feature Importance - Outliers (Forest {i+1})', fontsize=14)
        axes[1].set_xlabel('Feature Index')
        axes[1].set_ylabel('Tree Index')
        
        plt.tight_layout()
        
        if is_og_model:
            wandb.log({f"threshold_type_{threshold_type}/seed_{seed}/feature_importance_heatmap_original": wandb.Image(fig)})
        else:
            wandb.log({f"threshold_type_{threshold_type}/seed_{seed}/feature_importance_heatmap_pruned": wandb.Image(fig)})
        
        plt.close(fig)

# %%
def log_fi_diff(og_fi, pruned_fi, threshold_type):
    """
    Log the difference in features importance between the original and pruned model.
    
    Args:
        og_fi (np.ndarray): Feature importance of the original model.
        pruned_fi (np.ndarray): Feature importance of the pruned model.
        threshold_type (str): Type of thresholding used for feature selection.
    """
    fi_diff = pruned_fi - og_fi
    colors = ['green' if val > 0 else 'red' for val in fi_diff]

    plt.figure(figsize=(10, 5))
    plt.grid(True, axis='y', linestyle='--', alpha=0.7, zorder=0)
    plt.bar(range(len(fi_diff)), fi_diff, color=colors, zorder=3)
    plt.xticks(range(len(fi_diff)), range(len(fi_diff)))
    plt.xlabel('Feature Index')
    plt.ylabel('Change in Feature Importance (Pruned - Original)')
    plt.title('Difference in Feature Importance After Pruning')

    from matplotlib.patches import Patch
    legend_elements = [
        Patch(facecolor='green', edgecolor='black', label='Increase after pruning'),
        Patch(facecolor='red', edgecolor='black', label='Decrease after pruning')
    ]
    plt.legend(handles=legend_elements, loc='upper right')

    wandb.log({f"threshold_type_{threshold_type}/feature_importance_difference": wandb.Image(plt)})
    plt.close()

# %%
def log_estimators_summary(iforests, og_num_trees, threshold_type, seed):
    """
    Log the number of estimators in each Isolation Forest to wandb.

    Args:
        iforests (list): List of Isolation Forest models.
        seed (int): Random seed used for the models.
        og_num_trees (int): Original number of trees in the unpruned model.
        threshold_type (str): Type of thresholding used for feature selection.
    """

    # # Log per-forest statistics
    # for i, iforest in enumerate(iforests):
    #     forest_count = len(iforest.estimators_)
    #     forest_index = i + 1  # Use 1-based indexing for readability
        
    #     wandb.log({
    #         f"threshold_type_{threshold_type}/seed_{seed}/forest_{forest_index}/num_estimators": forest_count,
    #         # Percentage of trees retained compared to original 
    #         f"threshold_type_{threshold_type}/seed_{seed}/forest_{forest_index}/retention_rate": forest_count / og_num_trees,
    #         f"threshold_type_{threshold_type}/seed_{seed}/forest_{forest_index}/mean_estimators": np.mean(forest_count),
    #         f"threshold_type_{threshold_type}/seed_{seed}/forest_{forest_index}/min_estimators": np.min(forest_count),
    #         f"threshold_type_{threshold_type}/seed_{seed}/forest_{forest_index}/max_estimators": np.max(forest_count),
    #     })

    # wandb.log({
    #     f"threshold_type_{threshold_type}/seed_{seed}/overall_total_estimators": np.sum([len(iforest.estimators_) for iforest in iforests]),
    # })

    # Log summary table
    data = [[i+1, len(iforests[i].estimators_)] for i in range(len(iforests))]
    columns = ["Forest Index", "Number of Estimators"]
    wandb.log({f"threshold_type_{threshold_type}/seed_{seed}/estimators_table": wandb.Table(data=data, columns=columns)})

# %%
def log_features_summary(features_importance, selected_features, seed, threshold_type):
    """
    Log a summary of feature importances and selected meaningful features to wandb.
    Args:
        features_importance (np.ndarray): Array of feature importances.
        selected_features (list): List of indices of selected meaningful features for each forest.
        threshold_type (str): Type of thresholding used for feature selection.
    """

    for f in range(len(features_importance)):
        num_all_features = len(features_importance[f])
        num_meaningful_features = len(selected_features[f])
        # plot bar chart for each forest, highlighting selected features
        plt.figure(figsize=(10, 5))
        plt.grid(True, axis='y', linestyle='--', alpha=0.7, zorder=0)
        bars = plt.bar(range(len(features_importance[f])), features_importance[f], zorder=3)
        plt.xticks(range(len(features_importance[f])), range(len(features_importance[f])))
        plt.xlabel('Feature Index')
        plt.ylabel('Feature Importance')
        plt.ylim(bottom=0)
        for idx in selected_features[f]:
            bars[idx].set_color('orange')
        plt.legend(['Selected Features'], loc='upper right')
        plt.text(0.981, 0.88, f'Selected {num_meaningful_features}/{num_all_features} meaningful features', 
                 horizontalalignment='right', verticalalignment='top', transform=plt.gca().transAxes,
                 bbox=dict(facecolor='white', alpha=0.8, edgecolor='black'))
        plt.title(f'Feature Importance - Forest {f+1} (Seed {seed})')
        wandb.log({f"threshold_type_{threshold_type}/seed_{seed}/meaningful_features_selected": wandb.Image(plt)})
        plt.close()

# %% [markdown]
# ## Usage feature counter

# %%
def get_feature_usage(used_features, unique_features):
    """
    Calculating the feature usage in each tree for each forest.

    Args: 
        used_features (list): 
            - each element represents a forest and it is a list
                - each element of a forest is a tree and contains a list of features used in that tree
        unique_features (list): list of unique features used in the dataset.
    Returns:
        usage (np.ndarray): shape (num_forests, num_trees, num_features) 
            Each element is the count of how many times a feature is used in a tree of a forest.
        normalized_usage (np.ndarray): shape (num_forests, num_trees, num_features)
            Each element is the normalized count of how many times a feature is used in a tree of a forest. Normalization
            wrt to the total splits used in the tree. 
    """

    num_forests = len(used_features)
    num_trees = len(used_features[0])
    num_features = len(unique_features)

    usage = np.zeros((num_forests, num_trees, num_features), dtype=float)
    normalized_usage = np.zeros((num_forests, num_trees, num_features), dtype=float)

    # Iterate over each forest
    for f in range(num_forests):
        # Iterate over each tree in the forest
        for t in range(num_trees):
            internal_nodes_counter = 0
            # Iterate over each feature used in the tree
            for feature in used_features[f][t]:
                if feature in unique_features:
                    feature_index = unique_features.index(feature)
                    usage[f, t, feature_index] += 1
                if feature != -2:  # not a leaf node
                    internal_nodes_counter += 1
            
            # Normalize the usage by the number of internal nodes in the tree
            if internal_nodes_counter > 0:
                normalized_usage[f, t] = usage[f, t] / internal_nodes_counter
            else:
                raise ValueError(f"Tree {t} in forest {f} has no internal nodes, cannot normalize usage.")

    return usage, normalized_usage

# %% [markdown]
# ## Meaningful feature selection methods

# %%
def elbow_features_selection(feature_importances):
    """
    Selecting most important features based on the elbow method.

    Args:
        feature_importances (np.ndarray): Array of shape (num_forests, num_features)
            containing the feature importances for each forest.

    Returns:
        selected_features (list): List of lists, where each inner list contains the indices of the selected features for each forest.
        threshold_gaps (np.ndarray): Array of shape (num_forests,) containing the maximum gap thresholds for each forest.
        gaps (list): List of lists, where each inner list contains the gaps between consecutive feature importances for each forest.
    """

    n_forests, n_features = feature_importances.shape

    # Get the indexes of the features sorted by importance
    sorted_indices = np.argsort(feature_importances, axis=1)[:, ::-1]

    # Sort the feature importances based on the sorted indices
    sorted_importances = np.take_along_axis(feature_importances, sorted_indices, axis=1)

    selected_features, gaps = [], []
    threshold_gaps = np.zeros(n_forests, dtype=float)

    if n_features < 2: # Not enough features to compute gaps
        for f in range(n_forests):
            selected_idx = sorted_indices[f, :].tolist()
            selected_features.append(selected_idx)
            gaps.append([])
    else:
        # Calculate gaps between consecutive feature importances
        gaps_batch = sorted_importances[:, :-1] - sorted_importances[:, 1:]

        # Get the maximum gap for each forest
        max_gap_indices = np.argmax(gaps_batch + 1e-12 * np.random.rand(*gaps_batch.shape), axis=1)
        threshold_gaps = np.take_along_axis(gaps_batch, max_gap_indices[:, np.newaxis], axis=1).squeeze()

        # Select features based on the maximum gap
        for f in range(n_forests):
            num_to_select = max_gap_indices[f] + 1
            selected_idx_for_forest = sorted_indices[f, :num_to_select].tolist()
            selected_features.append(selected_idx_for_forest)
            gaps.append(gaps_batch[f, :].tolist())

    return selected_features, threshold_gaps, gaps

# %%
# TODO: add soft threshold

# %% [markdown]
# ## Selection of trees to be removed

# %%
def get_unique_usage_per_tree(normalized_usages, feature_importances, selected_features):
    """
    Compute the unique usage of selected features for each tree in each forest as weighted sum of features usage weighted by their importance.

    Args:
        normalized_usages (np.ndarray): Array of shape (num_forests, num_trees, num_features)
            containing the normalized feature usage for each tree in each forest.
        feature_importances (np.ndarray): Array of shape (num_forests, num_features)
            containing the feature importances for each forest.
        selected_features (list): List of lists, where each inner list contains the indices of the selected features for each forest.

    Returns:
        unique_usages (np.ndarray): Array of shape (num_forests, num_trees) containing the weighted usage for each tree in each forest.
    """

    n_forests, n_trees, n_features = normalized_usages.shape
    unique_usages = np.zeros((n_forests, n_trees), dtype=float)

    for f in range(n_forests):
        forest_selected_features = set(selected_features[f])
        forest_total_importance = np.sum(feature_importances[f, :])
        assert forest_total_importance > 0, f"Forest {f} has zero total importance, cannot compute unique usage."

        for t in range(n_trees):
            current_tree_weighted_usage = 0.0
            current_tree_weight_sum = 0.0

            for feature in range(n_features):
                if feature in forest_selected_features:
                    current_tree_weighted_usage += normalized_usages[f, t, feature] * feature_importances[f, feature]
                    current_tree_weight_sum += feature_importances[f, feature]

            assert current_tree_weight_sum > 0, f"Tree {t} in forest {f} has zero total importance, cannot compute unique usage."
            unique_usages[f, t] = current_tree_weighted_usage / current_tree_weight_sum
            
    return unique_usages

# %%
def get_unique_avg_usage_per_forest(normalized_usages, selected_features):
    """
    Compute the average usage of selected features across all trees in each forest.

    Args:
        normalized_usages (np.ndarray): Array of shape (num_forests, num_trees, num_features)
            containing the normalized feature usage for each tree in each forest.
        selected_features (list): List of lists, where each inner list contains the indices of the selected features for each forest.

    Returns:
        unique_avg_usage (np.ndarray): Array of shape (num_forests, num_features) containing the average usage of selected feature for each forest.
    """

    n_forests, _, n_features = normalized_usages.shape
    unique_avg_usage = np.zeros((n_forests, n_features), dtype=float)

    for f in range(n_forests):
        forest_selected_features = set(selected_features[f])

        for feature in range(n_features):
            if feature in forest_selected_features:
                unique_avg_usage[f, feature] = np.mean(normalized_usages[f, :, feature])

    return unique_avg_usage

def majority_voting(normalized_usages, selected_features, feature_importances):
    """ 
    Apply majority voting to compute weighted voting score 
    Args:
        normalized_usages (np.ndarray): Array of shape (num_forests, num_trees, num_features)
            containing the normalized feature usage for each tree in each forest.
        selected_features (list): List of lists, where each inner list contains the indices of the selected features for each forest.
        feature_importances (np.ndarray): Array of shape (num_forests, num_features)
            containing the feature importances for each forest.
    Returns:
        voting_scores (np.ndarray): Array of shape (num_forests, num_trees) containing the voting score for each tree in each forest.
    """
    
    n_forests, n_trees, n_features = normalized_usages.shape
    binary_scores = np.zeros((n_forests, n_trees, n_features), dtype=int)
    voting_scores = np.zeros((n_forests, n_trees), dtype=float)

    unique_avg_usage = get_unique_avg_usage_per_forest(normalized_usages, selected_features)

    for f in range(n_forests):
        forest_selected_features = set(selected_features[f])
        forest_total_importance = np.sum(feature_importances[f, :])
        assert forest_total_importance > 0, f"Forest {f} has zero total importance, cannot compute voting score."

        for t in range(n_trees):
            current_tree_weight_sum = 0.0

            for feature in range(n_features):
                if feature in forest_selected_features:
                    if normalized_usages[f, t, feature] > unique_avg_usage[f, feature]:
                        binary_scores[f, t, feature] = 1
                    current_tree_weight_sum += feature_importances[f, feature]

            assert current_tree_weight_sum > 0, f"Tree {t} in forest {f} has zero total importance, cannot compute voting score."
            voting_scores[f, t] = np.sum(np.multiply(binary_scores[f, t, :], feature_importances[f, :])) 

    return voting_scores

# %%
def remove_trees(iforests, unique_usages, thresholds):
    """
    For each forest, remove trees that have a feature usage below a certain threshold.

    Args:
        iforests (list): List of forests, each containing a list of trees.
        unique_usages (np.ndarray): Array of shape (num_forests, num_trees, num_features) 
            containing the usage of each feature in each tree.
        thresholds (list): List of thresholds for each forest to determine which trees to remove.

    Returns:
        pruned_forests (list): List of pruned forests with trees removed based on the thresholds.
    """
    pruned_forests = copy.deepcopy(iforests)

    n_forests = len(iforests)
    keep_mask = unique_usages > thresholds[:, np.newaxis]

    for f in range(n_forests):
        # Get the index of the forest to prune
        current_forest = pruned_forests[f]
        current_mask = keep_mask[f]
        og_estimators = current_forest.estimators_
        og_features = current_forest.estimators_features_

        # Filter and update the estimators and features based on the mask
        pruned_forests[f].estimators_ = [est for idx, est in enumerate(og_estimators) if current_mask[idx]]
        pruned_forests[f].estimators_features_ = [feat for idx, feat in enumerate(og_features) if current_mask[idx]]

        # Update also the internal attributes of the forest
        og_decision_paths = current_forest._decision_path_lengths
        pruned_forests[f]._decision_path_lengths = [path for idx, path in enumerate(og_decision_paths) if current_mask[idx]]

        og_avg_paths = current_forest._average_path_length_per_tree
        pruned_forests[f]._average_path_length_per_tree = [avg_path for idx, avg_path in enumerate(og_avg_paths) if current_mask[idx]]
        pruned_forests[f].n_estimators_ = len(pruned_forests[f].estimators_)
        
    return pruned_forests

# %%
def random_trees_removal(iforests, num_trees_to_remove):
    """
    For each forest, remove trees that have a feature usage below a certain threshold.

    Args:
        iforests (list): List of forests, each containing a list of trees.
        unique_usages (np.ndarray): Array of shape (num_forests, num_trees, num_features) 
            containing the usage of each feature in each tree.
        thresholds (list): List of thresholds for each forest to determine which trees to remove.

    Returns:
        pruned_forests (list): List of pruned forests with trees removed based on the thresholds.
    """
    pruned_forests = copy.deepcopy(iforests)

    n_forests = len(iforests)

    for f in range(n_forests):
        # Get the index of the forest to prune
        current_forest = pruned_forests[f]
        n_trees = len(current_forest.estimators_)

        if num_trees_to_remove >= n_trees:
            raise ValueError(f"Cannot remove {num_trees_to_remove} trees from forest {f} with only {n_trees} trees.")
        
        # Mask of trees to keep (True) and remove (False)
        keep_mask = np.ones(n_trees, dtype=bool)
        indices_to_remove = np.random.choice(n_trees, num_trees_to_remove, replace=False)
        keep_mask[indices_to_remove] = False

        og_estimators = current_forest.estimators_
        og_features = current_forest.estimators_features_

        # Filter and update the estimators and features based on the mask
        pruned_forests[f].estimators_ = [est for idx, est in enumerate(og_estimators) if keep_mask[idx]]
        pruned_forests[f].estimators_features_ = [feat for idx, feat in enumerate(og_features) if keep_mask[idx]]

        # Update also the internal attributes of the forest
        og_decision_paths = current_forest._decision_path_lengths
        pruned_forests[f]._decision_path_lengths = [path for idx, path in enumerate(og_decision_paths) if keep_mask[idx]]

        og_avg_paths = current_forest._average_path_length_per_tree
        pruned_forests[f]._average_path_length_per_tree = [avg_path for idx, avg_path in enumerate(og_avg_paths) if keep_mask[idx]]
        pruned_forests[f].n_estimators_ = len(pruned_forests[f].estimators_)
        
    return pruned_forests

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Parameters

# %%
num_trees = 100
max_samples = 256  
num_forests = 10
test_size = 0   # 0.1
seeds = [0, 1, 2, 3, 4]

# %%
threshold_type = 'percentile'  # 'random', 'mean', 'majority_voting', 'percentile' 
# selection_method = 'elbow'  # 'elbow', 'soft_threshold'
percentile = 50             # for percentile thresholding
num_trees_to_remove = 80    # for random removal

# %% [markdown]
# ## Experiment loop

# %%
# Initialize results list to store the results of each experiment
results = []
# Collect all datasets
datasets = odds_datasets.datasets_names

for i, dataset in tqdm.tqdm(enumerate(datasets), desc="Loading datasets", total=len(datasets)):

    f1_over_seeds = np.zeros((len(seeds), num_forests))
    avg_precision_over_seeds = np.zeros((len(seeds), num_forests))

    X,y = odds_datasets.load(dataset)
    # Get the unique features used in the dataset
    all_features = range(X.shape[1])

    for seed in tqdm.tqdm(seeds, desc=f"Processing dataset: {dataset}", leave=False):

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed) if test_size > 0 else (X, X, y, y)
        contamination = np.mean(y_train)
        X_train, y_train = shuffle(X_train, y_train, random_state=seed)

        # Init Weights & Biases run
        run = wandb.init(
            project="if_optimization",
            name=f"diffi_syn_seed_{seed}_forest_{num_forests}_trees_{num_trees}",
            config={
                "seed": seed,
                "dataset": dataset,
                "num_forests": num_forests,
                "num_trees": num_trees,
                "contamination": contamination,
                "max_samples": max_samples,
                "test_size": test_size,
                "thresholds": threshold_type,
                "percentile_value": percentile if threshold_type == 'percentile' else "N/A",            # for percentile thresholding
                "num_trees_to_remove": num_trees_to_remove if threshold_type == 'random' else "N/A",    # for random removal

            },
        )

        f1s, avg_precisions, fi_og, iforests, used_features, fis_out, fis_in = diffi_ranks(
            X_train,
            X_test,
            y_test,
            seed,
            n_iters=num_forests,
            contamination=contamination,
            num_trees=num_trees,  
        )

        mean_f1 = np.mean(f1s)
        mean_avg_precision = np.mean(avg_precisions)
        mean_fi_og = np.mean(fi_og, axis=0)

        log_feature_importance(mean_fi_og, threshold_type, og_model=True)
        log_fi_heatmap(fis_in, fis_out, threshold_type, seed, is_og_model=True)

        # ???
        f1_over_seeds[seed, :] = f1s
        avg_precision_over_seeds[seed, :] = avg_precisions

        pruned_iforests =  []
        if threshold_type == 'random':
            pruned_iforests = random_trees_removal(iforests, num_trees_to_remove=num_trees_to_remove)
        else:   # threshold_type in ['mean', 'percentile', 'majority_voting']
            # feature selection
            selected_features, gap_thresholds, gaps = elbow_features_selection(fi_og)
            log_features_summary(fi_og, selected_features, seed, threshold_type)
            
            # extract only the feature importances of the selected features
            unique_fi_og = np.zeros((num_forests, fi_og.shape[1]), dtype=float)
            for f in range(num_forests):
                forest_selected_features = set(selected_features[f])
                
                for sf in forest_selected_features:
                    unique_fi_og[f, sf] = fi_og[f, sf]
            # normalize the unique feature importances per forest
            normalized_unique_fi_og = np.divide(unique_fi_og, np.sum(unique_fi_og, axis=1, keepdims=True))
            # get feature usage
            usages, normalized_usages = get_feature_usage(used_features, all_features)

            thresholds = np.zeros(num_forests, dtype=float)

            if threshold_type == 'mean':
                unique_usages = get_unique_usage_per_tree(normalized_usages, normalized_unique_fi_og, selected_features)
                for f in range(num_forests):
                    thresholds[f] = np.mean(unique_usages[f, :])
                pruned_iforests = remove_trees(iforests, unique_usages, thresholds)
            elif threshold_type == 'percentile':
                unique_usages = get_unique_usage_per_tree(normalized_usages, normalized_unique_fi_og, selected_features)
                for f in range(num_forests):
                    thresholds[f] = np.percentile(unique_usages[f, :], percentile)
                pruned_iforests = remove_trees(iforests, unique_usages, thresholds)
            else:   # 'majority_voting'
                voting_scores = majority_voting(normalized_usages, selected_features, normalized_unique_fi_og)
                pruned_iforests = remove_trees(iforests, voting_scores, np.array([0.5]*num_forests))

        log_estimators_summary(pruned_iforests, run.config.num_trees, threshold_type, seed)

        f1s_pruned, avg_precisions_pruned, fi_pruned, fis_out_pruned, fis_in_pruned = diffi_ranks_evaluation_only(
            X_test, 
            y_test, 
            pruned_iforests
        )
            
        mean_f1_pruned = np.mean(f1s_pruned)
        mean_avg_precision_pruned = np.mean(avg_precisions_pruned)
        mean_fi_pruned = np.mean(fi_pruned, axis=0)

        log_feature_importance(mean_fi_pruned, threshold_type, og_model=False)
        log_fi_heatmap(fis_in_pruned, fis_out_pruned, threshold_type, seed, is_og_model=False)
        log_fi_diff(mean_fi_og, mean_fi_pruned, threshold_type)

        results.append([
            seed,
            f"{mean_f1:.4f}",
            f"{mean_f1_pruned:.4f}",
            f"{mean_avg_precision:.4f}",
            f"{mean_avg_precision_pruned:.4f}",
        ])

    headers = ["Seed", "F1 Score", "F1 Score Pruned", "Avg Precision", "Avg Precision Pruned"]
    table = tabulate(results, headers=headers, tablefmt="grid")

    # log performance metrics to wandb
    wandb.log({"results_table": wandb.Table(data=results, columns=headers)})
# Out:
# Loading datasets:   0%|          | 0/17 [00:00<?, ?it/s]
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_154816-jimvtpw2</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jimvtpw2' target="_blank">diffi_syn_seed_0_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jimvtpw2' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jimvtpw2</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_0_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jimvtpw2' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jimvtpw2</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_154816-jimvtpw2/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_154827-qih9ssxd</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qih9ssxd' target="_blank">diffi_syn_seed_1_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qih9ssxd' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qih9ssxd</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_1_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qih9ssxd' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qih9ssxd</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_154827-qih9ssxd/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_154839-acx08ivs</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/acx08ivs' target="_blank">diffi_syn_seed_2_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/acx08ivs' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/acx08ivs</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_2_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/acx08ivs' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/acx08ivs</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_154839-acx08ivs/logs</code>
# creating run (0.0s)
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_154851-g7eaeqdo</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/g7eaeqdo' target="_blank">diffi_syn_seed_3_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/g7eaeqdo' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/g7eaeqdo</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_3_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/g7eaeqdo' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/g7eaeqdo</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_154851-g7eaeqdo/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_154925-5q068qsk</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/5q068qsk' target="_blank">diffi_syn_seed_4_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/5q068qsk' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/5q068qsk</a>
# Loading datasets:   6%|▌         | 1/17 [01:21<21:47, 81.72s/it]
#  View run <strong style="color:#cdcd00">diffi_syn_seed_4_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/5q068qsk' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/5q068qsk</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 35 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_154925-5q068qsk/logs</code>
# creating run (0.0s)
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_154937-7ca98end</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/7ca98end' target="_blank">diffi_syn_seed_0_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/7ca98end' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/7ca98end</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_0_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/7ca98end' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/7ca98end</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_154937-7ca98end/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155031-19smk1gl</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/19smk1gl' target="_blank">diffi_syn_seed_1_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/19smk1gl' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/19smk1gl</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_1_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/19smk1gl' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/19smk1gl</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155031-19smk1gl/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155044-vxauywpw</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/vxauywpw' target="_blank">diffi_syn_seed_2_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/vxauywpw' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/vxauywpw</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_2_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/vxauywpw' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/vxauywpw</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155044-vxauywpw/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155056-i2bellxu</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/i2bellxu' target="_blank">diffi_syn_seed_3_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/i2bellxu' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/i2bellxu</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_3_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/i2bellxu' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/i2bellxu</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155056-i2bellxu/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155109-jihkxujd</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jihkxujd' target="_blank">diffi_syn_seed_4_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jihkxujd' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jihkxujd</a>
# Loading datasets:  12%|█▏        | 2/17 [03:07<24:01, 96.13s/it]
#  View run <strong style="color:#cdcd00">diffi_syn_seed_4_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jihkxujd' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jihkxujd</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 35 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155109-jihkxujd/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155124-lqj6ekpn</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/lqj6ekpn' target="_blank">diffi_syn_seed_0_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/lqj6ekpn' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/lqj6ekpn</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_0_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/lqj6ekpn' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/lqj6ekpn</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155124-lqj6ekpn/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155155-8tgresm5</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8tgresm5' target="_blank">diffi_syn_seed_1_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8tgresm5' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8tgresm5</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_1_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8tgresm5' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8tgresm5</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155155-8tgresm5/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155209-fyxx40wk</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fyxx40wk' target="_blank">diffi_syn_seed_2_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fyxx40wk' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fyxx40wk</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_2_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fyxx40wk' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fyxx40wk</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155209-fyxx40wk/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155225-9mzvnbdz</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9mzvnbdz' target="_blank">diffi_syn_seed_3_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9mzvnbdz' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9mzvnbdz</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_3_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9mzvnbdz' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9mzvnbdz</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155225-9mzvnbdz/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155239-nmjvvdi5</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/nmjvvdi5' target="_blank">diffi_syn_seed_4_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/nmjvvdi5' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/nmjvvdi5</a>
# Loading datasets:  18%|█▊        | 3/17 [04:38<21:49, 93.55s/it]
#  View run <strong style="color:#cdcd00">diffi_syn_seed_4_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/nmjvvdi5' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/nmjvvdi5</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 35 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155239-nmjvvdi5/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155254-mws7t1q1</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mws7t1q1' target="_blank">diffi_syn_seed_0_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mws7t1q1' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mws7t1q1</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_0_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mws7t1q1' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mws7t1q1</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155254-mws7t1q1/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155310-fuhf3pr9</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fuhf3pr9' target="_blank">diffi_syn_seed_1_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fuhf3pr9' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fuhf3pr9</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_1_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fuhf3pr9' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/fuhf3pr9</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155310-fuhf3pr9/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155325-yof4fdbj</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yof4fdbj' target="_blank">diffi_syn_seed_2_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yof4fdbj' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yof4fdbj</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_2_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yof4fdbj' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yof4fdbj</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155325-yof4fdbj/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155338-zwmouemf</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/zwmouemf' target="_blank">diffi_syn_seed_3_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/zwmouemf' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/zwmouemf</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_3_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/zwmouemf' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/zwmouemf</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155338-zwmouemf/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155355-c746wgdx</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/c746wgdx' target="_blank">diffi_syn_seed_4_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/c746wgdx' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/c746wgdx</a>
# Loading datasets:  24%|██▎       | 4/17 [05:54<18:44, 86.49s/it]
#  View run <strong style="color:#cdcd00">diffi_syn_seed_4_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/c746wgdx' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/c746wgdx</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 35 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155355-c746wgdx/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155410-h3jzzflu</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/h3jzzflu' target="_blank">diffi_syn_seed_0_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/h3jzzflu' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/h3jzzflu</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_0_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/h3jzzflu' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/h3jzzflu</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155410-h3jzzflu/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155424-3sfovij0</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3sfovij0' target="_blank">diffi_syn_seed_1_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3sfovij0' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3sfovij0</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_1_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3sfovij0' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3sfovij0</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155424-3sfovij0/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155437-kk3yfm7e</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/kk3yfm7e' target="_blank">diffi_syn_seed_2_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/kk3yfm7e' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/kk3yfm7e</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_2_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/kk3yfm7e' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/kk3yfm7e</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155437-kk3yfm7e/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155456-8arpapgl</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8arpapgl' target="_blank">diffi_syn_seed_3_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8arpapgl' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8arpapgl</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_3_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8arpapgl' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/8arpapgl</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155456-8arpapgl/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155508-oguvtydl</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/oguvtydl' target="_blank">diffi_syn_seed_4_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/oguvtydl' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/oguvtydl</a>
# Loading datasets:  29%|██▉       | 5/17 [07:19<17:11, 85.98s/it]
#  View run <strong style="color:#cdcd00">diffi_syn_seed_4_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/oguvtydl' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/oguvtydl</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 35 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155508-oguvtydl/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155535-eqy2qwne</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/eqy2qwne' target="_blank">diffi_syn_seed_0_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/eqy2qwne' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/eqy2qwne</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_0_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/eqy2qwne' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/eqy2qwne</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155535-eqy2qwne/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155549-yrv8884w</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yrv8884w' target="_blank">diffi_syn_seed_1_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yrv8884w' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yrv8884w</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_1_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yrv8884w' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/yrv8884w</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155549-yrv8884w/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155601-mg4a5g8x</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mg4a5g8x' target="_blank">diffi_syn_seed_2_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mg4a5g8x' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mg4a5g8x</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_2_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mg4a5g8x' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/mg4a5g8x</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155601-mg4a5g8x/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155620-pzofwd48</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pzofwd48' target="_blank">diffi_syn_seed_3_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pzofwd48' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pzofwd48</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_3_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pzofwd48' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pzofwd48</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_155620-pzofwd48/logs</code>
# creating run (0.0s)
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_155632-e5678e1g</code>
# ...
# Find logs at: <code>./wandb/run-20250827_160716-c12o9yqh/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_160732-3dy8mtcc</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3dy8mtcc' target="_blank">diffi_syn_seed_0_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3dy8mtcc' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3dy8mtcc</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_0_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3dy8mtcc' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/3dy8mtcc</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_160732-3dy8mtcc/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_160749-jmj4svq9</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jmj4svq9' target="_blank">diffi_syn_seed_1_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jmj4svq9' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jmj4svq9</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_1_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jmj4svq9' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/jmj4svq9</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_160749-jmj4svq9/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_160814-57mbjxs6</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/57mbjxs6' target="_blank">diffi_syn_seed_2_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/57mbjxs6' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/57mbjxs6</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_2_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/57mbjxs6' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/57mbjxs6</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_160814-57mbjxs6/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_160829-528m9jdo</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/528m9jdo' target="_blank">diffi_syn_seed_3_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/528m9jdo' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/528m9jdo</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_3_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/528m9jdo' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/528m9jdo</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_160829-528m9jdo/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_160901-03z40zm6</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/03z40zm6' target="_blank">diffi_syn_seed_4_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/03z40zm6' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/03z40zm6</a>
# Loading datasets:  76%|███████▋  | 13/17 [21:02<06:45, 101.37s/it]
#  View run <strong style="color:#cdcd00">diffi_syn_seed_4_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/03z40zm6' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/03z40zm6</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 35 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_160901-03z40zm6/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_160918-9gt6veho</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9gt6veho' target="_blank">diffi_syn_seed_0_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9gt6veho' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9gt6veho</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_0_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9gt6veho' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/9gt6veho</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_160918-9gt6veho/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_160934-qu09ycsy</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qu09ycsy' target="_blank">diffi_syn_seed_1_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qu09ycsy' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qu09ycsy</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_1_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qu09ycsy' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/qu09ycsy</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_160934-qu09ycsy/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_160958-ifmhohl7</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/ifmhohl7' target="_blank">diffi_syn_seed_2_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/ifmhohl7' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/ifmhohl7</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_2_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/ifmhohl7' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/ifmhohl7</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_160958-ifmhohl7/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_161014-pgkfba88</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pgkfba88' target="_blank">diffi_syn_seed_3_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pgkfba88' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pgkfba88</a>
#  View run <strong style="color:#cdcd00">diffi_syn_seed_3_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pgkfba88' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/pgkfba88</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 34 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_161014-pgkfba88/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/Users/sebastianosanson/Documents/Master Thesis/Master-Thesis/wandb/run-20250827_161030-zg1wokxk</code>
# Syncing run <strong><a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/zg1wokxk' target="_blank">diffi_syn_seed_4_forest_10_trees_100</a></strong> to <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a>
#  View run at <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/zg1wokxk' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/zg1wokxk</a>

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">diffi_syn_seed_4_forest_10_trees_100</strong> at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/hnm10qz5' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization/runs/hnm10qz5</a><br> View project at: <a href='https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization' target="_blank">https://wandb.ai/sanson-sebastiano-00-universita-di-padova/if_optimization</a><br>Synced 5 W&B file(s), 35 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250827_154716-hnm10qz5/logs</code>
